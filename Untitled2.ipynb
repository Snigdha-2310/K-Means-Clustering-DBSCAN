# %%
# !pip install numpy

# %%
# !pip install pandas

import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd

# !pip install scikit-learn

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
# ... other scikit-learn imports as needed

# %%
# Assuming the mall dataset is a CSV file named 'mall_customers.csv'
# Replace with the actual file name if it's different.
data = pd.read_csv('mall-customers-data.csv')

# Display the first few rows of the dataset to get a glimpse of its structure
print(data.head())

# Summarize the dataset using descriptive statistics
print(data.describe())

# Get information about the data types and missing values
print(data.info())
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40
#        customer_id         age  annual_income  spending_score
# count   200.000000  200.000000     200.000000      200.000000
# mean    100.500000   38.850000      60.560000       50.200000
# std      57.879185   13.969007      26.264721       25.823522
# min       1.000000   18.000000      15.000000        1.000000
# 25%      50.750000   28.750000      41.500000       34.750000
# 50%     100.500000   36.000000      61.500000       50.000000
# 75%     150.250000   49.000000      78.000000       73.000000
# max     200.000000   70.000000     137.000000       99.000000
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
from sklearn.cluster import KMeans

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('mall-customers-data.csv')
features = data[[  'annual_income','spending_score']]

# Determine the optimal number of clusters using the elbow method
wss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(features)
    wss.append(kmeans.inertia_)

plt.plot(range(1, 11), wss, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
plt.title('Elbow Method')
plt.show()

# Apply KMeans with a chosen k
k = 3  # Adjust based on elbow method
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(features)
data['Cluster'] = kmeans.labels_

# Visualize clusters
plt.scatter(features['annual_income'], features['spending_score'], c=data['Cluster'], cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label='Centroids')
plt.xlabel('annual_income')
plt.ylabel('spending_score')
plt.legend()
plt.title(f'KMeans Clustering with {k} clusters')
plt.show()
